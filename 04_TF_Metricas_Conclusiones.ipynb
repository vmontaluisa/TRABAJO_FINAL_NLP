# %% [markdown]
# **4. Reporte de métricas y conclusiones**

# %%
1.	Accuracy (Exactitud):
	•	Logistic Regression obtuvo una accuracy ligeramente superior (0.78 vs. 0.76).
	•	Ambos modelos con los parametros plamnteados obtuvieron  un rendimiento similar en términos de clasificación correcta general

# %%
	2.	Precision (Precisión):
	•	Logistic Regression tiene mejor precisión (0.80 vs. 0.76).
	•	Esto sugiere que Logistic Regression clasifica de manera más confiable las instancias positivas, reduciendo falsos positivos.

# %%
3. Tiempo de Entrenamiento
	•	Logistic Regression:	se genero un entrenamiento rápido, debido a la simplicidad del modelo.
	•	LSTM:	Es	un entrenamiento más lento, ya que LSTM debe tener muchas más operaciones debido a su arquitectura recurrente y el cálculo secuencial. se incremento el numero de epocas pero el resultado no mejoro

# %%
Recomendaciones para mejorar ambos modelos:
	1.	Para Logistic Regression: Experimentar con  otros transformadores de características, como TF-IDF o embeddings preentrenados.
	2.	Para LSTM: Incrementa el tamaño del dataset para mejorar la generalización. Pruebar mas  hiperparámetros como la cantidad de neuronas, tasa de aprendizaje, y aumenta el número de épocas(aunque se aumentaron a 10).
